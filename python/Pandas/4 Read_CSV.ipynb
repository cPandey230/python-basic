# %%
#Reading Csv
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx")
# df = pd.read_csv(r"C:\Users\chandan\Desktop\WsCubePyhton\CsV File Data\Customer Call List.csv")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",nrows =3)
# df = pd.read_csv(r"C:\Users\chandan\Desktop\WsCubePyhton\CsV File Data\Customer Call List.csv")
df
# Out:
#    CustomerID First_Name Last_Name  Phone_Number                Address  \
# 0        1001      Frodo   Baggins  123-545-5421  123 Shire Lane, Shire
# 1        1002       Abed     Nadir  123/643/9775    93 West Main Street
# 2        1003     Walter    /White    7066950392     298 Drugs Driveway
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 0             Yes             No               True
# 1              No            Yes              False
# 2               N            NaN               True

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",usecols = ["CustomerID", "Address"] )
# df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\CsV File Data\Customer Call List.xlsx",usecols = [0,2] )
df
# Out:
#     CustomerID                                Address
# 0         1001                  123 Shire Lane, Shire
# 1         1002                    93 West Main Street
# 2         1003                     298 Drugs Driveway
# 3         1004  980 Paper Avenue, Pennsylvania, 18503
# 4         1005                       123 Dragons Road
# 5         1006                       768 City Parkway
# 6         1007                      1209 South Street
# 7         1008                          98 Clue Drive
# 8         1009                       123 Middle Earth
# 9         1010             25th Main Street, New York
# 10        1011                  612 Shire Lane, Shire
# 11        1012                   2394 Hogwarts Avenue
# 12        1013                       2039 Main Street
# 13        1014                       343 City Parkway
# 14        1015                          214 HR Avenue
# 15        1016                   2395 Hogwarts Avenue
# ...

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",skiprows=[0,3])
df
# Out:
#     1001     Frodo      Baggins  123-545-5421  \
# 0   1002      Abed        Nadir  123/643/9775
# 1   1004    Dwight      Schrute  123-543-2345
# 2   1005       Jon         Snow  876|678|3469
# 3   1006       Ron      Swanson  304-762-2467
# 4   1007      Jeff       Winger           NaN
# 5   1008  Sherlock       Holmes  876|678|3469
# 6   1009   Gandalf          NaN           N/a
# 7   1010     Peter       Parker  123-545-5421
# 8   1011   Samwise       Gamgee           NaN
# 9   1012     Harry    ...Potter    7066950392
# 10  1013       Don       Draper  123-543-2345
# 11  1014    Leslie        Knope  876|678|3469
# 12  1015      Toby  Flenderson_  304-762-2467
# 13  1016       Ron      Weasley  123-545-5421
# 14  1017  Michael         Scott  123/643/9775
# 15  1018     Clark         Kent    7066950392
# 16  1019     Creed       Braton           N/a
# 17  1020    Anakin    Skywalker  876|678|3469
# 18  1020    Anakin    Skywalker  876|678|3469
#
# ...

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",index_col="CustomerID")
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",header = 2).head(10)
df
# Out:
#    1002      Abed      Nadir  123/643/9775  \
# 0  1003    Walter     /White    7066950392
# 1  1004    Dwight    Schrute  123-543-2345
# 2  1005       Jon       Snow  876|678|3469
# 3  1006       Ron    Swanson  304-762-2467
# 4  1007      Jeff     Winger           NaN
# 5  1008  Sherlock     Holmes  876|678|3469
# 6  1009   Gandalf        NaN           N/a
# 7  1010     Peter     Parker  123-545-5421
# 8  1011   Samwise     Gamgee           NaN
# 9  1012     Harry  ...Potter    7066950392
#
#                      93 West Main Street   No  Yes  False
# 0                     298 Drugs Driveway    N  NaN   True
# 1  980 Paper Avenue, Pennsylvania, 18503  Yes    Y   True
# 2                       123 Dragons Road    Y   No   True
# 3                       768 City Parkway  Yes  Yes   True
# 4                      1209 South Street   No   No  False
# 5                          98 Clue Drive    N   No  False
# 6                       123 Middle Earth  Yes  NaN  False
# ...

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",names=["col1","col2","col3","col4","col5","col6","col7","col8"]).tail(10)
df
# Out:
#     col1      col2         col3          col4                            col5  \
# 11  1012     Harry    ...Potter    7066950392            2394 Hogwarts Avenue
# 12  1013       Don       Draper  123-543-2345                2039 Main Street
# 13  1014    Leslie        Knope  876|678|3469                343 City Parkway
# 14  1015      Toby  Flenderson_  304-762-2467                   214 HR Avenue
# 15  1016       Ron      Weasley  123-545-5421            2395 Hogwarts Avenue
# 16  1017  Michael         Scott  123/643/9775  121 Paper Avenue, Pennsylvania
# 17  1018     Clark         Kent    7066950392                 3498 Super Lane
# 18  1019     Creed       Braton           N/a                             N/a
# 19  1020    Anakin    Skywalker  876|678|3469     910 Tatooine Road, Tatooine
# 20  1020    Anakin    Skywalker  876|678|3469     910 Tatooine Road, Tatooine
#
#    col6 col7   col8
# 11    Y  NaN   True
# 12  Yes    N  False
# 13  Yes   No  False
# 14    N   No  False
# ...

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",header = None,prefix = "col").head(10)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\CsV File Data\Customer Call List.xlsx",header = None,prefix = "col").head(10)
#       2 df
#
# TypeError: read_excel() got an unexpected keyword argument 'prefix'

# %%
df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\Pandas\CsV File Data\Customer Call List.xlsx",dtype=["CustomerID" : "float"])
df
# Out:
#   Cell In[21], line 1
#     df = pd.read_excel(r"C:\Users\chandan\Desktop\WsCubePyhton\CsV File Data\Customer Call List.xlsx",dtype=["CustomerID" : "float"])
#                                                                                                                           ^
# SyntaxError: invalid syntax
