# %%
#Insert
import pandas as pd

# %%
var = pd.DataFrame(
    {
        "A" : [1,2,3,4,5],
        "B" : [6,7,8,9,10],
    }
)
var
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
var.insert(1,"C",var["A"]*10)
var
# Out:
#    A   C   B
# 0  1  10   6
# 1  2  20   7
# 2  3  30   8
# 3  4  40   9
# 4  5  50  10

# %%
var.insert(3,"D",[11,12,13,14,15])
var
# Out:
#    A   C   B   D
# 0  1  10   6  11
# 1  2  20   7  12
# 2  3  30   8  13
# 3  4  40   9  14
# 4  5  50  10  15

# %%
var = pd.DataFrame(
    {
        "A" : [1,2,3,4,5],
        "B" : [6,7,8,9,10],
    }
)
var
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
var["C"] = var["A"][:3]
var
# Out:
#    A   B    C
# 0  1   6  1.0
# 1  2   7  2.0
# 2  3   8  3.0
# 3  4   9  NaN
# 4  5  10  NaN

# %%
#Delete

# %%
var = pd.DataFrame(
    {
        "A" : [1,2,3,4,5],
        "B" : [6,7,8,9,10],
        "C" : [11,12,13,14,15],
    }
)
var
# Out:
#    A   B   C
# 0  1   6  11
# 1  2   7  12
# 2  3   8  13
# 3  4   9  14
# 4  5  10  15

# %%
var.pop('B')
var
# Out:
#    A   C
# 0  1  11
# 1  2  12
# 2  3  13
# 3  4  14
# 4  5  15

# %%
del var["A"]
var
# Out:
#     C
# 0  11
# 1  12
# 2  13
# 3  14
# 4  15
